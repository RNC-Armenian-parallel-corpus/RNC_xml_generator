# %% [markdown]
# ## 1. Нужные библиотеки

# %%
! git clone 'https://github.com/RNC-Armenian-parallel-corpus/RNC_xml_generator'
# Out:
# Cloning into 'RNC_xml_generator'...
# remote: Enumerating objects: 73, done.
# remote: Counting objects: 100% (73/73), done.
# remote: Compressing objects: 100% (64/64), done.
# remote: Total 73 (delta 31), reused 23 (delta 5), pack-reused 0 (from 0)
# Receiving objects: 100% (73/73), 151.13 KiB | 6.30 MiB/s, done.
# Resolving deltas: 100% (31/31), done.

# %%
! pip install git+https://github.com/RNC-Armenian-parallel-corpus/razdel_armenian.git
# Out:
# ...
#   Cloning https://github.com/RNC-Armenian-parallel-corpus/razdel_armenian.git to /tmp/pip-req-build-n32s0em7
#   Running command git clone --filter=blob:none --quiet https://github.com/RNC-Armenian-parallel-corpus/razdel_armenian.git /tmp/pip-req-build-n32s0em7
#   Resolved https://github.com/RNC-Armenian-parallel-corpus/razdel_armenian.git to commit 1032e6cc41bff92f36eb8e21face5547d4110f6a
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for razdel: filename=razdel-0.5.0-py3-none-any.whl size=21288 sha256=2c170c5b69d3ffb27ab8b53402f87d207ee8a50dbbb06e0718157ab7e6e90949
#   Stored in directory: /tmp/pip-ephem-wheel-cache-hgujqmkj/wheels/be/c6/ca/ea0de4740e421f64c6009c7723853bd18ca58a9334c3ebd117
# Successfully built razdel
# ...

# %%
! pip install uniparser_eastern_armenian
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 17.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.8/59.8 kB 2.2 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## 2. Данные для обработки

# %%
import os

try:
    os.makedirs('RNC_xml_generator/texts/input')
    os.makedirs('RNC_xml_generator/texts/output')
except FileExistsError:
    print(f'Some directory already exists')
# Out:
# Some directory already exists

# %% [markdown]
# Поместить в папку ...texts/input выровненные тексты в формате .xlsx

# %%
! ls 'RNC_xml_generator/texts/input'
# Out:
# charents-nairi.xlsx		    saltykov_schedrin-dva_generala.xlsx
# chekhov-moya_zhizn.xlsx		    shirvanzade-qaos_1.xlsx
# chekhov-step.xlsx		    tumanyan-axe.xlsx
# dashtents-zov_paxarej_1.xlsx	    tumanyan-barekendan.xlsx
# dovlatov-kurtka_fernana_lezhe.xlsx  tumanyan-feast.xlsx
# dovlatov-zimnyaya_shapka.xlsx	    tumanyan-fool.xlsx
# gogol-taras_bulba.xlsx		    tumanyan-fox.xlsx
# kuprin-poedinok.xlsx		    tumanyan-king.xlsx
# pushkin-kapitanskaya_dochka.xlsx    tumanyan-liar.xlsx
# raffi-iskryi_1.xlsx		    tumanyan-nazar.xlsx
# raffi-zolotoy_petuh.xlsx	    tumanyan-talking_fish.xlsx

# %% [markdown]
# ## 3. Генерация xml и отчёта

# %%
# Google colab version, locally use UNIX ! cd instead
# %cd '/content/RNC_xml_generator'
# Out:
# /content/RNC_xml_generator

# %%
! ls
# Out:
# classes.py		   main.py	  requirements.txt
# eanc2rnc_tag_converter.py  readme_assets  run_xml_generator.ipynb
# hy_translit.py		   README.md	  texts

# %%
! python main.py --hye hy --rus ru
# Out:
# Analyzer imported
# texts/input/pushkin-kapitanskaya_dochka.xlsx...
# Used columns: ['ru', 'hy']
# Execution time: 32.5257 seconds
# texts/input/kuprin-poedinok.xlsx...
# Used columns: ['ru', 'hy']
# Execution time: 29.0485 seconds
# texts/input/tumanyan-liar.xlsx...
# Used columns: ['hy', 'ru']
# Execution time: 0.0719 seconds
# texts/input/tumanyan-talking_fish.xlsx...
# Used columns: ['hy', 'ru']
# Execution time: 0.3048 seconds
# texts/input/dovlatov-zimnyaya_shapka.xlsx...
# Used columns: ['ru', 'hy']
# Execution time: 1.4874 seconds
# texts/input/shirvanzade-qaos_1.xlsx...
# Used columns: ['hy', 'ru']
# Execution time: 18.7677 seconds
# texts/input/raffi-zolotoy_petuh.xlsx...
# Used columns: ['hy', 'ru']
# Execution time: 12.0338 seconds
# texts/input/dovlatov-kurtka_fernana_lezhe.xlsx...
# Used columns: ['ru', 'hy']
# Execution time: 1.3461 seconds
# texts/input/dashtents-zov_paxarej_1.xlsx...
# Used columns: ['hy', 'ru']
# Execution time: 24.3790 seconds
# ...

# %% [markdown]
# ## 4. Скачивание файлов

# %%
! ls
# Out:
# classes.py		   main.py	  requirements.txt
# eanc2rnc_tag_converter.py  __pycache__	  run_xml_generator.ipynb
# errors.log		   readme_assets  texts
# hy_translit.py		   README.md

# %%
# pass
