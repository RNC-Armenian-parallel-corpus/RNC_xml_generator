# %% [markdown]
# ## 1. Нужные библиотеки

# %%
! git clone 'https://github.com/RNC-Armenian-parallel-corpus/RNC_xml_generator'
# Out:
# fatal: destination path 'RNC_xml_generator' already exists and is not an empty directory.

# %%
! pip install git+https://github.com/RNC-Armenian-parallel-corpus/razdel_armenian.git
# Out:
# Collecting git+https://github.com/RNC-Armenian-parallel-corpus/razdel_armenian.git
#   Cloning https://github.com/RNC-Armenian-parallel-corpus/razdel_armenian.git to /tmp/pip-req-build-pkk9j4cz
#   Running command git clone --filter=blob:none --quiet https://github.com/RNC-Armenian-parallel-corpus/razdel_armenian.git /tmp/pip-req-build-pkk9j4cz
#   Resolved https://github.com/RNC-Armenian-parallel-corpus/razdel_armenian.git to commit 4e13758d12c7bbf020647435a51c6a2ff940bb38
#   Preparing metadata (setup.py) ... done

# %%
! pip install uniparser_eastern_armenian
# Out:
# Requirement already satisfied: uniparser_eastern_armenian in /usr/local/lib/python3.12/dist-packages (2.1.2)
# Requirement already satisfied: uniparser-morph>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from uniparser_eastern_armenian) (2.9.4)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.12/dist-packages (from uniparser_eastern_armenian) (6.5.2)
# Requirement already satisfied: textdistance>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from uniparser-morph>=2.2.0->uniparser_eastern_armenian) (4.6.3)

# %% [markdown]
# ## 2. Данные для обработки

# %%
import os

try:
    os.makedirs('RNC_xml_generator/texts/input')
    os.makedirs('RNC_xml_generator/texts/output')
except FileExistsError:
    print(f'Some directory already exists')
# Out:
# Some directory already exists

# %% [markdown]
# Поместить в папку ...texts/input выровненные тексты в формате .xlsx

# %%
! ls 'RNC_xml_generator/texts/input'
# Out:
# axe.xlsx

# %% [markdown]
# ## 3. Генерация xml

# %%
# Google colab version, locally use UNIX ! cd instead
# %cd '/content/RNC_xml_generator'
# Out:
# /content/RNC_xml_generator

# %%
! ls
# Out:
# classes.py		   hy_translit.py  readme_assets     texts
# eanc2rnc_tag_converter.py  main.py	   README.md
# errors.log		   __pycache__	   requirements.txt

# %%
! python main.py --hye hy --rus ru
# Out:
# Analyzer imported
# texts/input/axe.xlsx...
# Used columns: ['hy', 'ru']
# Execution time: 12.0666 seconds
